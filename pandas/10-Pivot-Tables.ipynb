# %% [markdown]
# # Pivot Tables
#
# Pivoting data can sometimes help clarify relationships and connections.
#
# Full documentation on a variety of related pivot methods: https://pandas.pydata.org/docs/user_guide/reshaping.html
#
# ## Data

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('Sales_Funnel_CRM.csv')

# %%
df
# Out:
#     Account Number       Company       Contact Account Manager  \
# 0          2123398        Google   Larry Pager    Edward Thorp
# 1          2123398        Google   Larry Pager    Edward Thorp
# 2          2123398        Google   Larry Pager    Edward Thorp
# 3          2192650          BOBO   Larry Pager    Edward Thorp
# 4           420496          IKEA     Elon Tusk    Edward Thorp
# 5           636685    Tesla Inc.     Elon Tusk    Edward Thorp
# 6           636685    Tesla Inc.     Elon Tusk    Edward Thorp
# 7          1216870     Microsoft   Will Grates    Edward Thorp
# 8          2200450       Walmart   Will Grates    Edward Thorp
# 9           405886         Apple  Cindy Phoner  Claude Shannon
# 10          470248  Exxon Mobile  Cindy Phoner  Claude Shannon
# 11          698032           ATT  Cindy Phoner  Claude Shannon
# 12          698032           ATT  Cindy Phoner  Claude Shannon
# 13          902797    CVS Health  Emma Gordian  Claude Shannon
# 14         2046943    Salesforce  Emma Gordian  Claude Shannon
# 15         2169499         Cisco  Emma Gordian  Claude Shannon
# 16         2169499         Cisco  Emma Gordian  Claude Shannon
#
#             Product  Licenses  Sale Price        Status
# 0         Analytics       150     2100000     Presented
# 1        Prediction       150      700000     Presented
# 2          Tracking       300      350000  Under Review
# 3         Analytics       150     2450000          Lost
# 4         Analytics       300     4550000           Won
# 5         Analytics       300     2800000  Under Review
# 6        Prediction       150      700000     Presented
# 7          Tracking       300      350000  Under Review
# 8         Analytics       150     2450000          Lost
# 9         Analytics       300     4550000           Won
# 10        Analytics       150     2100000     Presented
# 11         Tracking       150      350000  Under Review
# 12       Prediction       150      700000     Presented
# 13         Tracking       450      490000           Won
# 14        Analytics       750     7000000           Won
# 15        Analytics       300     4550000          Lost
# 16  GPS Positioning       300      350000     Presented

# %% [markdown]
# # The pivot() method
#
# The pivot method reshapes data based on column values and reassignment of the index. Keep in mind, it doesn't always make sense to pivot data. In our machine learning lessons, we will see that our data doesn't need to be pivoted. Pivot methods are mainly for data analysis,visualization, and exploration.
#
# ----
#
# Here is an image showing the idea behind a pivot() call:
#
# <img src='reshaping_pivot.png'>

# %%
help(pd.pivot)
# Out:
# Help on function pivot in module pandas.core.reshape.pivot:
#
# pivot(data: 'DataFrame', *, index: 'IndexLabel | None' = None, columns: 'IndexLabel | None' = None, values: 'IndexLabel | None' = None) -> 'DataFrame'
#     Return reshaped DataFrame organized by given index / column values.
#
#     Reshape data (produce a "pivot" table) based on column values. Uses
#     unique values from specified `index` / `columns` to form axes of the
#     resulting DataFrame. This function does not support data
#     aggregation, multiple values will result in a MultiIndex in the
#     columns. See the :ref:`User Guide <reshaping>` for more on reshaping.
#
#     Parameters
#     ----------
#     data : DataFrame
#     index : str or object or a list of str, optional
#         Column to use to make new frame's index. If None, uses
#         existing index.
#
#         .. versionchanged:: 1.1.0
#            Also accept list of index names.
#
#     columns : str or object or a list of str
#         Column to use to make new frame's columns.
#
#         .. versionchanged:: 1.1.0
#            Also accept list of columns names.
#
#     values : str, object or a list of the previous, optional
#         Column(s) to use for populating new frame's values. If not
#         specified, all remaining columns will be used and the result will
#         have hierarchically indexed columns.
#
#     Returns
#     -------
#     DataFrame
#         Returns reshaped DataFrame.
#
#     Raises
#     ------
#     ValueError:
#         When there are any `index`, `columns` combinations with multiple
#         values. `DataFrame.pivot_table` when you need to aggregate.
#
#     See Also
#     --------
#     DataFrame.pivot_table : Generalization of pivot that can handle
#         duplicate values for one index/column pair.
#     DataFrame.unstack : Pivot based on the index values instead of a
#         column.
#     wide_to_long : Wide panel to long format. Less flexible but more
#         user-friendly than melt.
#
#     Notes
#     -----
#     For finer-tuned control, see hierarchical indexing documentation along
#     with the related stack/unstack methods.
#
#     Reference :ref:`the user guide <reshaping.pivot>` for more examples.
#
#     Examples
#     --------
#     >>> df = pd.DataFrame({'foo': ['one', 'one', 'one', 'two', 'two',
#     ...                            'two'],
#     ...                    'bar': ['A', 'B', 'C', 'A', 'B', 'C'],
#     ...                    'baz': [1, 2, 3, 4, 5, 6],
#     ...                    'zoo': ['x', 'y', 'z', 'q', 'w', 't']})
#     >>> df
#         foo   bar  baz  zoo
#     0   one   A    1    x
#     1   one   B    2    y
#     2   one   C    3    z
#     3   two   A    4    q
#     4   two   B    5    w
#     5   two   C    6    t
#
#     >>> df.pivot(index='foo', columns='bar', values='baz')
#     bar  A   B   C
#     foo
#     one  1   2   3
#     two  4   5   6
#
#     >>> df.pivot(index='foo', columns='bar')['baz']
#     bar  A   B   C
#     foo
#     one  1   2   3
#     two  4   5   6
#
#     >>> df.pivot(index='foo', columns='bar', values=['baz', 'zoo'])
#           baz       zoo
#     bar   A  B  C   A  B  C
#     foo
#     one   1  2  3   x  y  z
#     two   4  5  6   q  w  t
#
#     You could also assign a list of column names or a list of index names.
#
#     >>> df = pd.DataFrame({
#     ...        "lev1": [1, 1, 1, 2, 2, 2],
#     ...        "lev2": [1, 1, 2, 1, 1, 2],
#     ...        "lev3": [1, 2, 1, 2, 1, 2],
#     ...        "lev4": [1, 2, 3, 4, 5, 6],
#     ...        "values": [0, 1, 2, 3, 4, 5]})
#     >>> df
#         lev1 lev2 lev3 lev4 values
#     0   1    1    1    1    0
#     1   1    1    2    2    1
#     2   1    2    1    3    2
#     3   2    1    2    4    3
#     4   2    1    1    5    4
#     5   2    2    2    6    5
#
#     >>> df.pivot(index="lev1", columns=["lev2", "lev3"],values="values")
#     lev2    1         2
#     lev3    1    2    1    2
#     lev1
#     1     0.0  1.0  2.0  NaN
#     2     4.0  3.0  NaN  5.0
#
#     >>> df.pivot(index=["lev1", "lev2"], columns=["lev3"],values="values")
#           lev3    1    2
#     lev1  lev2
#        1     1  0.0  1.0
#              2  2.0  NaN
#        2     1  4.0  3.0
#              2  NaN  5.0
#
#     A ValueError is raised if there are any duplicates.
#
#     >>> df = pd.DataFrame({"foo": ['one', 'one', 'two', 'two'],
#     ...                    "bar": ['A', 'A', 'B', 'C'],
#     ...                    "baz": [1, 2, 3, 4]})
#     >>> df
#        foo bar  baz
#     0  one   A    1
#     1  one   A    2
#     2  two   B    3
#     3  two   C    4
#
#     Notice that the first two rows are the same for our `index`
#     and `columns` arguments.
#
#     >>> df.pivot(index='foo', columns='bar', values='baz')
#     Traceback (most recent call last):
#        ...
#     ValueError: Index contains duplicate entries, cannot reshape

# %% [markdown]
# ----
# #### Note: Common Point of Confusion: Students often just randomly pass in index,column, and value choices in an attempt to see the changes. This often just leads to formatting errors. You should first go through this checklist BEFORE running a pivot():
#
# * What question are you trying to answer?
# * What would a dataframe that answers the question look like? Does it need a pivot()
# * What you want the resulting pivot to look like? Do you need all the original columns?
#
# -----

# %%
df
# Out:
#     Account Number       Company       Contact Account Manager  \
# 0          2123398        Google   Larry Pager    Edward Thorp
# 1          2123398        Google   Larry Pager    Edward Thorp
# 2          2123398        Google   Larry Pager    Edward Thorp
# 3          2192650          BOBO   Larry Pager    Edward Thorp
# 4           420496          IKEA     Elon Tusk    Edward Thorp
# 5           636685    Tesla Inc.     Elon Tusk    Edward Thorp
# 6           636685    Tesla Inc.     Elon Tusk    Edward Thorp
# 7          1216870     Microsoft   Will Grates    Edward Thorp
# 8          2200450       Walmart   Will Grates    Edward Thorp
# 9           405886         Apple  Cindy Phoner  Claude Shannon
# 10          470248  Exxon Mobile  Cindy Phoner  Claude Shannon
# 11          698032           ATT  Cindy Phoner  Claude Shannon
# 12          698032           ATT  Cindy Phoner  Claude Shannon
# 13          902797    CVS Health  Emma Gordian  Claude Shannon
# 14         2046943    Salesforce  Emma Gordian  Claude Shannon
# 15         2169499         Cisco  Emma Gordian  Claude Shannon
# 16         2169499         Cisco  Emma Gordian  Claude Shannon
#
#             Product  Licenses  Sale Price        Status
# 0         Analytics       150     2100000     Presented
# 1        Prediction       150      700000     Presented
# 2          Tracking       300      350000  Under Review
# 3         Analytics       150     2450000          Lost
# 4         Analytics       300     4550000           Won
# 5         Analytics       300     2800000  Under Review
# 6        Prediction       150      700000     Presented
# 7          Tracking       300      350000  Under Review
# 8         Analytics       150     2450000          Lost
# 9         Analytics       300     4550000           Won
# 10        Analytics       150     2100000     Presented
# 11         Tracking       150      350000  Under Review
# 12       Prediction       150      700000     Presented
# 13         Tracking       450      490000           Won
# 14        Analytics       750     7000000           Won
# 15        Analytics       300     4550000          Lost
# 16  GPS Positioning       300      350000     Presented

# %% [markdown]
# --------
# ** What type of question does a pivot help answer?**
#
# **Imagine we wanted to know, how many licenses of each product type did Google purchase? Currently the way the data is formatted is hard to read. Let's pivot it so this is clearer, we will take a subset of the data for the question at hand.**

# %%
# Let's take a subset, otherwise we'll get an error due to duplicate rows and data
licenses = df[['Company','Product','Licenses']]
licenses
# Out:
#          Company          Product  Licenses
# 0         Google        Analytics       150
# 1         Google       Prediction       150
# 2         Google         Tracking       300
# 3           BOBO        Analytics       150
# 4           IKEA        Analytics       300
# 5     Tesla Inc.        Analytics       300
# 6     Tesla Inc.       Prediction       150
# 7      Microsoft         Tracking       300
# 8        Walmart        Analytics       150
# 9          Apple        Analytics       300
# 10  Exxon Mobile        Analytics       150
# 11           ATT         Tracking       150
# 12           ATT       Prediction       150
# 13    CVS Health         Tracking       450
# 14    Salesforce        Analytics       750
# 15         Cisco        Analytics       300
# 16         Cisco  GPS Positioning       300

# %%
pd.pivot(data=licenses,index='Company',columns='Product',values='Licenses')
# Out:
# Product       Analytics  GPS Positioning  Prediction  Tracking
# Company
#  Google           150.0              NaN       150.0     300.0
# ATT                 NaN              NaN       150.0     150.0
# Apple             300.0              NaN         NaN       NaN
# BOBO              150.0              NaN         NaN       NaN
# CVS Health          NaN              NaN         NaN     450.0
# Cisco             300.0            300.0         NaN       NaN
# Exxon Mobile      150.0              NaN         NaN       NaN
# IKEA              300.0              NaN         NaN       NaN
# Microsoft           NaN              NaN         NaN     300.0
# Salesforce        750.0              NaN         NaN       NaN
# Tesla Inc.        300.0              NaN       150.0       NaN
# Walmart           150.0              NaN         NaN       NaN

# %% [markdown]
# ## The pivot_table() method
#
# Similar to the pivot() method, the pivot_table() can add aggregation functions to a pivot call.

# %%
df
# Out:
#     Account Number       Company       Contact Account Manager  \
# 0          2123398        Google   Larry Pager    Edward Thorp
# 1          2123398        Google   Larry Pager    Edward Thorp
# 2          2123398        Google   Larry Pager    Edward Thorp
# 3          2192650          BOBO   Larry Pager    Edward Thorp
# 4           420496          IKEA     Elon Tusk    Edward Thorp
# 5           636685    Tesla Inc.     Elon Tusk    Edward Thorp
# 6           636685    Tesla Inc.     Elon Tusk    Edward Thorp
# 7          1216870     Microsoft   Will Grates    Edward Thorp
# 8          2200450       Walmart   Will Grates    Edward Thorp
# 9           405886         Apple  Cindy Phoner  Claude Shannon
# 10          470248  Exxon Mobile  Cindy Phoner  Claude Shannon
# 11          698032           ATT  Cindy Phoner  Claude Shannon
# 12          698032           ATT  Cindy Phoner  Claude Shannon
# 13          902797    CVS Health  Emma Gordian  Claude Shannon
# 14         2046943    Salesforce  Emma Gordian  Claude Shannon
# 15         2169499         Cisco  Emma Gordian  Claude Shannon
# 16         2169499         Cisco  Emma Gordian  Claude Shannon
#
#             Product  Licenses  Sale Price        Status
# 0         Analytics       150     2100000     Presented
# 1        Prediction       150      700000     Presented
# 2          Tracking       300      350000  Under Review
# 3         Analytics       150     2450000          Lost
# 4         Analytics       300     4550000           Won
# 5         Analytics       300     2800000  Under Review
# 6        Prediction       150      700000     Presented
# 7          Tracking       300      350000  Under Review
# 8         Analytics       150     2450000          Lost
# 9         Analytics       300     4550000           Won
# 10        Analytics       150     2100000     Presented
# 11         Tracking       150      350000  Under Review
# 12       Prediction       150      700000     Presented
# 13         Tracking       450      490000           Won
# 14        Analytics       750     7000000           Won
# 15        Analytics       300     4550000          Lost
# 16  GPS Positioning       300      350000     Presented

# %%
# Notice Account Number sum() doesn't make sense to keep/use
pd.pivot_table(df,index="Company",aggfunc='sum')
# Out:
# /tmp/ipykernel_17744/1477459291.py:2: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   pd.pivot_table(df,index="Company",aggfunc='sum')
#               Account Number  Licenses  Sale Price
# Company
#  Google              6370194       600     3150000
# ATT                  1396064       300     1050000
# Apple                 405886       300     4550000
# BOBO                 2192650       150     2450000
# CVS Health            902797       450      490000
# Cisco                4338998       600     4900000
# Exxon Mobile          470248       150     2100000
# IKEA                  420496       300     4550000
# Microsoft            1216870       300      350000
# Salesforce           2046943       750     7000000
# Tesla Inc.           1273370       450     3500000
# Walmart              2200450       150     2450000

# %%
# Either grab the columns
pd.pivot_table(df,index="Company",aggfunc='sum')[['Licenses','Sale Price']]
# Out:
# /tmp/ipykernel_17744/2639572049.py:2: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   pd.pivot_table(df,index="Company",aggfunc='sum')[['Licenses','Sale Price']]
#               Licenses  Sale Price
# Company
#  Google            600     3150000
# ATT                300     1050000
# Apple              300     4550000
# BOBO               150     2450000
# CVS Health         450      490000
# Cisco              600     4900000
# Exxon Mobile       150     2100000
# IKEA               300     4550000
# Microsoft          300      350000
# Salesforce         750     7000000
# Tesla Inc.         450     3500000
# Walmart            150     2450000

# %%
# Or state them as wanted values
pd.pivot_table(df,index="Company",aggfunc='sum',values=['Licenses','Sale Price'])
# Out:
#               Licenses  Sale Price
# Company
#  Google            600     3150000
# ATT                300     1050000
# Apple              300     4550000
# BOBO               150     2450000
# CVS Health         450      490000
# Cisco              600     4900000
# Exxon Mobile       150     2100000
# IKEA               300     4550000
# Microsoft          300      350000
# Salesforce         750     7000000
# Tesla Inc.         450     3500000
# Walmart            150     2450000

# %%
df.groupby('Company').sum()[['Licenses','Sale Price']]
# Out:
# /tmp/ipykernel_17744/1525839501.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Company').sum()[['Licenses','Sale Price']]
#               Licenses  Sale Price
# Company
#  Google            600     3150000
# ATT                300     1050000
# Apple              300     4550000
# BOBO               150     2450000
# CVS Health         450      490000
# Cisco              600     4900000
# Exxon Mobile       150     2100000
# IKEA               300     4550000
# Microsoft          300      350000
# Salesforce         750     7000000
# Tesla Inc.         450     3500000
# Walmart            150     2450000

# %%
pd.pivot_table(df,index=["Account Manager","Contact"],values=['Sale Price'],aggfunc='sum')
# Out:
#                               Sale Price
# Account Manager Contact
# Claude Shannon  Cindy Phoner     7700000
#                 Emma Gordian    12390000
# Edward Thorp    Elon Tusk        8050000
#                 Larry Pager      5600000
#                 Will Grates      2800000

# %% [markdown]
# Columns are optional - they provide an additional way to segment the actual values you care about. The aggregation functions are applied to the values you list.

# %%
pd.pivot_table(df,index=["Account Manager","Contact"],values=["Sale Price"],columns=["Product"],aggfunc=[np.sum])
# Out:
#                                      sum
#                               Sale Price
# Product                        Analytics GPS Positioning Prediction  Tracking
# Account Manager Contact
# Claude Shannon  Cindy Phoner   6650000.0             NaN   700000.0  350000.0
#                 Emma Gordian  11550000.0        350000.0        NaN  490000.0
# Edward Thorp    Elon Tusk      7350000.0             NaN   700000.0       NaN
#                 Larry Pager    4550000.0             NaN   700000.0  350000.0
#                 Will Grates    2450000.0             NaN        NaN  350000.0

# %%
pd.pivot_table(df,index=["Account Manager","Contact"],values=["Sale Price"],columns=["Product"],aggfunc=[np.sum],fill_value=0)
# Out:
#                                     sum
#                              Sale Price
# Product                       Analytics GPS Positioning Prediction Tracking
# Account Manager Contact
# Claude Shannon  Cindy Phoner    6650000               0     700000   350000
#                 Emma Gordian   11550000          350000          0   490000
# Edward Thorp    Elon Tusk       7350000               0     700000        0
#                 Larry Pager     4550000               0     700000   350000
#                 Will Grates     2450000               0          0   350000

# %%
# Can add multiple agg functions
pd.pivot_table(df,index=["Account Manager","Contact"],values=["Sale Price"],columns=["Product"],
               aggfunc=[np.sum,np.mean],fill_value=0)
# Out:
#                                     sum                                      \
#                              Sale Price
# Product                       Analytics GPS Positioning Prediction Tracking
# Account Manager Contact
# Claude Shannon  Cindy Phoner    6650000               0     700000   350000
#                 Emma Gordian   11550000          350000          0   490000
# Edward Thorp    Elon Tusk       7350000               0     700000        0
#                 Larry Pager     4550000               0     700000   350000
#                 Will Grates     2450000               0          0   350000
#
#                                    mean
#                              Sale Price
# Product                       Analytics GPS Positioning Prediction Tracking
# Account Manager Contact
# Claude Shannon  Cindy Phoner    3325000               0     700000   350000
#                 Emma Gordian    5775000          350000          0   490000
# Edward Thorp    Elon Tusk       3675000               0     700000        0
#                 Larry Pager     2275000               0     700000   350000
#                 Will Grates     2450000               0          0   350000

# %%
# Can add on multiple columns
new_df = pd.pivot_table(df,index=["Account Manager","Contact"],values=["Sale Price","Licenses"],columns=["Product"],
               aggfunc=[np.sum],fill_value=0)
new_df
# Out:
#                                    sum                                      \
#                               Licenses
# Product                      Analytics GPS Positioning Prediction Tracking
# Account Manager Contact
# Claude Shannon  Cindy Phoner       450               0        150      150
#                 Emma Gordian      1050             300          0      450
# Edward Thorp    Elon Tusk          600               0        150        0
#                 Larry Pager        300               0        150      300
#                 Will Grates        150               0          0      300
#
#
#                              Sale Price
# Product                       Analytics GPS Positioning Prediction Tracking
# Account Manager Contact
# Claude Shannon  Cindy Phoner    6650000               0     700000   350000
#                 Emma Gordian   11550000          350000          0   490000
# Edward Thorp    Elon Tusk       7350000               0     700000        0
#                 Larry Pager     4550000               0     700000   350000
#                 Will Grates     2450000               0          0   350000

# %%
# Can add on multiple columns
pd.pivot_table(df,index=["Account Manager","Contact","Product"],values=["Sale Price","Licenses"],
               aggfunc=[np.sum],fill_value=0)
# Out:
#                                                   sum
#                                              Licenses Sale Price
# Account Manager Contact      Product
# Claude Shannon  Cindy Phoner Analytics            450    6650000
#                              Prediction           150     700000
#                              Tracking             150     350000
#                 Emma Gordian Analytics           1050   11550000
#                              GPS Positioning      300     350000
#                              Tracking             450     490000
# Edward Thorp    Elon Tusk    Analytics            600    7350000
#                              Prediction           150     700000
#                 Larry Pager  Analytics            300    4550000
#                              Prediction           150     700000
#                              Tracking             300     350000
#                 Will Grates  Analytics            150    2450000
#                              Tracking             300     350000

# %%
# get Final "ALL" with margins = True
# Can add on multiple columns
pd.pivot_table(df,index=["Account Manager","Contact","Product"],values=["Sale Price","Licenses"],
               aggfunc=[np.sum],fill_value=0,margins=True)
# Out:
#                                                   sum
#                                              Licenses Sale Price
# Account Manager Contact      Product
# Claude Shannon  Cindy Phoner Analytics            450    6650000
#                              Prediction           150     700000
#                              Tracking             150     350000
#                 Emma Gordian Analytics           1050   11550000
#                              GPS Positioning      300     350000
#                              Tracking             450     490000
# Edward Thorp    Elon Tusk    Analytics            600    7350000
#                              Prediction           150     700000
#                 Larry Pager  Analytics            300    4550000
#                              Prediction           150     700000
#                              Tracking             300     350000
#                 Will Grates  Analytics            150    2450000
#                              Tracking             300     350000
# All                                              4500   36540000

# %%
pd.pivot_table(df,index=["Account Manager","Status"],values=["Sale Price"],
               aggfunc=[np.sum],fill_value=0,margins=True)
# Out:
#                                     sum
#                              Sale Price
# Account Manager Status
# Claude Shannon  Lost            4550000
#                 Presented       3150000
#                 Under Review     350000
#                 Won            12040000
# Edward Thorp    Lost            4900000
#                 Presented       3500000
#                 Under Review    3500000
#                 Won             4550000
# All                            36540000

# %% [markdown]
# ----

# %%
# Extra

# %%
new_df
# Out:
#                                    sum                                      \
#                               Licenses
# Product                      Analytics GPS Positioning Prediction Tracking
# Account Manager Contact
# Claude Shannon  Cindy Phoner       450               0        150      150
#                 Emma Gordian      1050             300          0      450
# Edward Thorp    Elon Tusk          600               0        150        0
#                 Larry Pager        300               0        150      300
#                 Will Grates        150               0          0      300
#
#
#                              Sale Price
# Product                       Analytics GPS Positioning Prediction Tracking
# Account Manager Contact
# Claude Shannon  Cindy Phoner    6650000               0     700000   350000
#                 Emma Gordian   11550000          350000          0   490000
# Edward Thorp    Elon Tusk       7350000               0     700000        0
#                 Larry Pager     4550000               0     700000   350000
#                 Will Grates     2450000               0          0   350000

# %%
new_df.stack()
# Out:
#                                                   sum
#                                              Licenses Sale Price
# Account Manager Contact      Product
# Claude Shannon  Cindy Phoner Analytics            450    6650000
#                              GPS Positioning        0          0
#                              Prediction           150     700000
#                              Tracking             150     350000
#                 Emma Gordian Analytics           1050   11550000
#                              GPS Positioning      300     350000
#                              Prediction             0          0
#                              Tracking             450     490000
# Edward Thorp    Elon Tusk    Analytics            600    7350000
#                              GPS Positioning        0          0
#                              Prediction           150     700000
#                              Tracking               0          0
#                 Larry Pager  Analytics            300    4550000
#                              GPS Positioning        0          0
#                              Prediction           150     700000
#                              Tracking             300     350000
#                 Will Grates  Analytics            150    2450000
#                              GPS Positioning        0          0
#                              Prediction             0          0
#                              Tracking             300     350000

# %%
new_df.stack(0)
# Out:
#                                   Licenses                             \
# Product                          Analytics GPS Positioning Prediction
# Account Manager Contact
# Claude Shannon  Cindy Phoner sum       450               0        150
#                 Emma Gordian sum      1050             300          0
# Edward Thorp    Elon Tusk    sum       600               0        150
#                 Larry Pager  sum       300               0        150
#                 Will Grates  sum       150               0          0
#
#                                           Sale Price                  \
# Product                          Tracking  Analytics GPS Positioning
# Account Manager Contact
# Claude Shannon  Cindy Phoner sum      150    6650000               0
#                 Emma Gordian sum      450   11550000          350000
# Edward Thorp    Elon Tusk    sum        0    7350000               0
#                 Larry Pager  sum      300    4550000               0
#                 Will Grates  sum      300    2450000               0
#
#
# Product                          Prediction Tracking
# Account Manager Contact
# Claude Shannon  Cindy Phoner sum     700000   350000
#                 Emma Gordian sum          0   490000
# Edward Thorp    Elon Tusk    sum     700000        0
#                 Larry Pager  sum     700000   350000
#                 Will Grates  sum          0   350000

# %%
new_df.stack(1)
# Out:
#                                               sum                             \
# Product                                 Analytics GPS Positioning Prediction
# Account Manager Contact
# Claude Shannon  Cindy Phoner Licenses         450               0        150
#                              Sale Price   6650000               0     700000
#                 Emma Gordian Licenses        1050             300          0
#                              Sale Price  11550000          350000          0
# Edward Thorp    Elon Tusk    Licenses         600               0        150
#                              Sale Price   7350000               0     700000
#                 Larry Pager  Licenses         300               0        150
#                              Sale Price   4550000               0     700000
#                 Will Grates  Licenses         150               0          0
#                              Sale Price   2450000               0          0
#
#
# Product                                 Tracking
# Account Manager Contact
# Claude Shannon  Cindy Phoner Licenses        150
#                              Sale Price   350000
#                 Emma Gordian Licenses        450
#                              Sale Price   490000
# Edward Thorp    Elon Tusk    Licenses          0
#                              Sale Price        0
#                 Larry Pager  Licenses        300
#                              Sale Price   350000
#                 Will Grates  Licenses        300
#                              Sale Price   350000

# %%
new_df.stack([0, 1])
# Out:
# Product                                      Analytics  GPS Positioning  \
# Account Manager Contact
# Claude Shannon  Cindy Phoner sum Licenses          450                0
#                                  Sale Price    6650000                0
#                 Emma Gordian sum Licenses         1050              300
#                                  Sale Price   11550000           350000
# Edward Thorp    Elon Tusk    sum Licenses          600                0
#                                  Sale Price    7350000                0
#                 Larry Pager  sum Licenses          300                0
#                                  Sale Price    4550000                0
#                 Will Grates  sum Licenses          150                0
#                                  Sale Price    2450000                0
#
# Product                                      Prediction  Tracking
# Account Manager Contact
# Claude Shannon  Cindy Phoner sum Licenses           150       150
#                                  Sale Price      700000    350000
#                 Emma Gordian sum Licenses             0       450
#                                  Sale Price           0    490000
# Edward Thorp    Elon Tusk    sum Licenses           150         0
#                                  Sale Price      700000         0
#                 Larry Pager  sum Licenses           150       300
#                                  Sale Price      700000    350000
#                 Will Grates  sum Licenses             0       300
#                                  Sale Price           0    350000

# %%
new_df.stack([1, 2]).unstack('Contact')
# Out:
#                                                     sum             \
# Contact                                    Cindy Phoner  Elon Tusk
# Account Manager            Product
# Claude Shannon  Licenses   Analytics              450.0        NaN
#                            GPS Positioning          0.0        NaN
#                            Prediction             150.0        NaN
#                            Tracking               150.0        NaN
#                 Sale Price Analytics          6650000.0        NaN
#                            GPS Positioning          0.0        NaN
#                            Prediction          700000.0        NaN
#                            Tracking            350000.0        NaN
# Edward Thorp    Licenses   Analytics                NaN      600.0
#                            GPS Positioning          NaN        0.0
#                            Prediction               NaN      150.0
#                            Tracking                 NaN        0.0
#                 Sale Price Analytics                NaN  7350000.0
#                            GPS Positioning          NaN        0.0
#                            Prediction               NaN   700000.0
#                            Tracking                 NaN        0.0
#
#                                                                      \
# Contact                                    Emma Gordian Larry Pager
# Account Manager            Product
# Claude Shannon  Licenses   Analytics             1050.0         NaN
#                            GPS Positioning        300.0         NaN
#                            Prediction               0.0         NaN
#                            Tracking               450.0         NaN
#                 Sale Price Analytics         11550000.0         NaN
#                            GPS Positioning     350000.0         NaN
#                            Prediction               0.0         NaN
#                            Tracking            490000.0         NaN
# Edward Thorp    Licenses   Analytics                NaN       300.0
#                            GPS Positioning          NaN         0.0
#                            Prediction               NaN       150.0
#                            Tracking                 NaN       300.0
#                 Sale Price Analytics                NaN   4550000.0
#                            GPS Positioning          NaN         0.0
#                            Prediction               NaN    700000.0
#                            Tracking                 NaN    350000.0
#
#
# Contact                                    Will Grates
# Account Manager            Product
# Claude Shannon  Licenses   Analytics               NaN
#                            GPS Positioning         NaN
#                            Prediction              NaN
#                            Tracking                NaN
#                 Sale Price Analytics               NaN
#                            GPS Positioning         NaN
#                            Prediction              NaN
#                            Tracking                NaN
# Edward Thorp    Licenses   Analytics             150.0
#                            GPS Positioning         0.0
#                            Prediction              0.0
#                            Tracking              300.0
#                 Sale Price Analytics         2450000.0
#                            GPS Positioning         0.0
#                            Prediction              0.0
#                            Tracking           350000.0

# %%
import datetime

df = pd.DataFrame(
    {
        "A": ["one", "one", "two", "three"] * 6,
        "B": ["A", "B", "C"] * 8,
        "C": ["foo", "foo", "foo", "bar", "bar", "bar"] * 4,
        "D": np.random.randn(24),
        "E": np.random.randn(24),
        "F": [datetime.datetime(2013, i, 1) for i in range(1, 13)]
        + [datetime.datetime(2013, i, 15) for i in range(1, 13)],
    }
)
df
# Out:
#         A  B    C         D         E          F
# 0     one  A  foo -1.339609  1.417512 2013-01-01
# 1     one  B  foo  0.762850 -0.046119 2013-02-01
# 2     two  C  foo -1.017193 -0.295067 2013-03-01
# 3   three  A  bar  0.778167 -0.037617 2013-04-01
# 4     one  B  bar  0.389948 -2.494020 2013-05-01
# 5     one  C  bar -0.142447  0.842200 2013-06-01
# 6     two  A  foo -2.288991 -1.394640 2013-07-01
# 7   three  B  foo -0.799660 -1.115377 2013-08-01
# 8     one  C  foo  0.403333 -1.337223 2013-09-01
# 9     one  A  bar  2.094182 -0.371315 2013-10-01
# 10    two  B  bar -0.060493 -0.757361 2013-11-01
# 11  three  C  bar -0.669830 -1.030588 2013-12-01
# 12    one  A  foo -1.487368 -0.397485 2013-01-15
# 13    one  B  foo -0.140624  0.782803 2013-02-15
# 14    two  C  foo -0.348666  0.766228 2013-03-15
# 15  three  A  bar  1.831044  2.536530 2013-04-15
# 16    one  B  bar -0.105629  0.626296 2013-05-15
# 17    one  C  bar -0.675918  1.654066 2013-06-15
# 18    two  A  foo -0.077941  0.430938 2013-07-15
# 19  three  B  foo -0.248577  1.067574 2013-08-15
# 20    one  C  foo  1.162768 -0.576028 2013-09-15
# 21    one  A  bar -1.081189 -0.830684 2013-10-15
# 22    two  B  bar -0.227582 -0.610611 2013-11-15
# 23  three  C  bar -0.209644 -0.539195 2013-12-15

# %%
pd.pivot_table(df, values="D", index=["A", "B"], columns=["C"])
# Out:
# C             bar       foo
# A     B
# one   A  0.506497 -1.413489
#       B  0.142160  0.311113
#       C -0.409183  0.783051
# three A  1.304605       NaN
#       B       NaN -0.524118
#       C -0.439737       NaN
# two   A       NaN -1.183466
#       B -0.144037       NaN
#       C       NaN -0.682930

# %%
df.pivot_table(
    index=["A", "B"],
    columns="C",
    values=["D", "E"],
    margins=True,
    aggfunc=np.std
)
# Out:
#                 D                             E
# C             bar       foo       All       bar       foo       All
# A     B
# one   A  2.245327  0.104482  1.706727  0.324823  1.283396  0.997825
#       B  0.350426  0.638853  0.431848  2.206397  0.586136  1.517396
#       C  0.377221  0.537001  0.785724  0.574076  0.538246  1.351571
# three A  0.744496       NaN  0.744496  1.820197       NaN  1.820197
#       B       NaN  0.389674  0.389674       NaN  1.543579  1.543579
#       C  0.325401       NaN  0.325401  0.347468       NaN  0.347468
# two   A       NaN  1.563448  1.563448       NaN  1.290878  1.290878
#       B  0.118150       NaN  0.118150  0.103768       NaN  0.103768
#       C       NaN  0.472720  0.472720       NaN  0.750449  0.750449
# All      0.972059  0.989883  0.987789  1.332626  0.955863  1.110356
